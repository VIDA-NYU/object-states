# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd

# %%
import pathtrees as pt
from object_states.config import get_cfg
from object_states.util.build_nn import load_data, dump_db
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/bea/ptg/object-states/scripts/Dump DB.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import pathtrees as pt
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from object_states.config import get_cfg
#       <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> from object_states.util.build_nn import load_data, dump_db
#
# ModuleNotFoundError: No module named 'object_states'

# %%
config_name = 'config/static.yaml'

# %%
cfg = get_cfg(config_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/bea/ptg/object-states/scripts/Dump DB.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> cfg = get_cfg(config_name)
#
# NameError: name 'get_cfg' is not defined

# %%
tree = pt.tree(cfg.DATASET.ROOT, {
    'embeddings/{field_name}/{video_id}/{emb_type}/{track_id}.npz': 'emb_file',
    '{emb_type}.lancedb': 'db_fname',
    'embs.npz': 'pkl',
})
tree
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/bea/ptg/object-states/scripts/Dump DB.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> tree = pt.tree(cfg.DATASET.ROOT, {
#       <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     'embeddings/{field_name}/{video_id}/{emb_type}/{track_id}.npz': 'emb_file',
#       <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     '{emb_type}.lancedb': 'db_fname',
#       <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     'embs.npz': 'pkl',
#       <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> })
#       <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> tree
#
# NameError: name 'cfg' is not defined

# %%
emb_type = 'clip'
data_file_pattern = tree.emb_file.specify(emb_type=emb_type).glob_format()
data_file_pattern
# Out:
# '/datasets/static_eval/embeddings/*/*/clip/*.npz'

# %%
df = load_data(cfg, data_file_pattern)
print(df.shape)
df.head()
# Out:
# set()
# folded_kitchen_lightsoff 0 (1, 4)
# folded_kitchen_lightson 0 (1, 4)
# folded_nursing_lightsoff 0 (1, 4)
# folded_nursing_lightson 0 (1, 4)
# folded_office_lightsoff 0 (1, 4)
# folded_office_lightson 0 (1, 4)
# folded_orange_booth_lightsoff 0 (1, 4)
# folded_orange_booth_lightson 0 (1, 4)
# folded_printer 0 (1, 4)
# folded_staircase 0 (1, 4)
# folded_window 0 (1, 4)
# oatmeal_2023.06.16-20.08.08 0 (9, 4)
# oatmeal_2023.06.16-20.18.26 0 (9, 4)
# oatmeal_2023.06.16-20.33.26 0 (9, 4)
# oatmeal_2023.06.30-20.10.42 0 (8, 4)
# oatmeal_2023.06.30-20.21.07 0 (8, 4)
# oatmeal_mit-eval 0 (9, 4)
# on_plate_pinwheel_kitchen_lightsoff 0 (1, 4)
# on_plate_pinwheel_kitchen_lightson 0 (1, 4)
# on_plate_pinwheel_nursing_lightsoff 0 (1, 4)
# on_plate_pinwheel_nursing_lightson 0 (1, 4)
# on_plate_pinwheel_office_lightsoff 0 (1, 4)
# on_plate_pinwheel_office_lightson 0 (1, 4)
# on_plate_pinwheel_orange_booth_lightsoff 0 (1, 4)
# on_plate_pinwheel_orange_booth_lightson 0 (1, 4)
# on_plate_pinwheel_printer 0 (1, 4)
# on_plate_pinwheel_staircase 0 (1, 4)
# on_plate_pinwheel_window 0 (1, 4)
# on_plate_quesadilla_kitchen_lightsoff 0 (1, 4)
# on_plate_quesadilla_kitchen_lightson 1 (1, 4)
# on_plate_quesadilla_nursing_lightsoff 1 (1, 4)
# on_plate_quesadilla_nursing_lightson 1 (1, 4)
# on_plate_quesadilla_office_lightsoff 1 (1, 4)
# on_plate_quesadilla_office_lightson 1 (1, 4)
# on_plate_quesadilla_printer 1 (1, 4)
# package_kitchen_lightsoff 0 (1, 4)
# package_kitchen_lightson 0 (1, 4)
# package_nursingroom_lightsoff 0 (1, 4)
# package_nursingroom_lightson 2 (1, 4)
# package_office_lightsoff 0 (1, 4)
# package_office_lightson 0 (1, 4)
# package_orangebooth_lightsoff 5 (1, 4)
# package_orangebooth_lightson 0 (1, 4)
# package_printerroom_lightson 0 (1, 4)
# package_stairwell_as-is 20 (1, 4)
# package_window_lightson 20 (1, 4)
# pb_jelly_kitchen_lightsoff 1 (1, 4)
# pb_jelly_kitchen_lightson 1 (1, 4)
# pb_jelly_nursingroom_lightsoff 2 (1, 4)
# pb_jelly_nursingroom_lightson 1 (1, 4)
# pb_jelly_office_lightsoff 2 (1, 4)
# pb_jelly_office_lightson 1 (1, 4)
# pb_jelly_printerroom_lightsoff 1 (1, 4)
# peanut-butter_kitchen_lightsoff 0 (1, 4)
# peanut-butter_kitchen_lightson 0 (1, 4)
# peanut-butter_nursingroom_lightsoff 0 (1, 4)
# peanut-butter_nursingroom_lightson 0 (1, 4)
# peanut-butter_office_lightsoff 0 (1, 4)
# peanut-butter_office_lightson 0 (1, 4)
# peanut-butter_orangeroom_lightsoff 0 (1, 4)
# peanut-butter_orangeroom_lightson 0 (1, 4)
# peanut-butter_printerroom_lightsoff 0 (1, 4)
# peanut-butter_stairwell_as-is 0 (1, 4)
# peanut-butter_window_lightson 0 (1, 4)
# pinwheels_2023.03.01-21.35.14 0 (5, 4)
# pinwheels_2023.03.01-21.35.14 0 (1, 4)
# pinwheels_2023.03.02-22.56.36 1 (7, 4)
# pinwheels_2023.03.02-22.56.36 0 (2, 4)
# pinwheels_2023.03.02-22.56.36 0 (5, 4)
# pinwheels_2023.03.08-17.46.28 9 (7, 4)
# pinwheels_2023.03.08-17.46.28 9 (2, 4)
# pinwheels_2023.03.08-17.46.28 9 (5, 4)
# pinwheels_2023.03.30-16.38.48 4 (7, 4)
# pinwheels_2023.03.30-16.38.48 4 (2, 4)
# pinwheels_2023.03.30-16.50.36 0 (7, 4)
# pinwheels_2023.03.30-16.50.36 0 (2, 4)
# pinwheels_2023.04.03-19.38.08 0 (7, 4)
# pinwheels_2023.04.03-19.38.08 0 (2, 4)
# pinwheels_2023.04.04-18.33.59 0 (7, 4)
# pinwheels_2023.04.04-18.33.59 0 (2, 4)
# pinwheels_2023.04.04-18.33.59 0 (5, 4)
# pinwheels_2023.04.04-19.50.02 0 (7, 4)
# pinwheels_2023.04.04-19.50.02 0 (2, 4)
# pinwheels_mit-eval 91 (7, 4)
# pinwheels_mit-eval 0 (2, 4)
# pinwheels_mit-eval 0 (5, 4)
# plain_kitchen_lightsoff 0 (1, 4)
# plain_kitchen_lightson 0 (1, 4)
# plain_nursingroom_lightsoff 0 (1, 4)
# plain_nursingroom_lightson 0 (1, 4)
# plain_office_lightsoff 0 (1, 4)
# plain_office_lightson 0 (1, 4)
# plain_orangebooth_lightsoff 0 (1, 4)
# plain_orangebooth_lightson 0 (1, 4)
# plain_printerroom_lightsoff 0 (1, 4)
# plain_stairwell_as-is 0 (1, 4)
# plain_window_lightson 0 (1, 4)
# quesadilla_2023.06.16-18.53.43 1 (8, 4)
# quesadilla_2023.06.16-18.53.43 0 (2, 4)
# quesadilla_2023.06.16-18.53.43 0 (2, 4)
# quesadilla_2023.06.16-18.57.48 1 (8, 4)
# quesadilla_2023.06.16-18.57.48 0 (2, 4)
# quesadilla_2023.06.16-18.57.48 0 (2, 4)
# quesadilla_2023.06.16-19.00.58 1 (8, 4)
# quesadilla_2023.06.16-19.00.58 0 (2, 4)
# quesadilla_2023.06.16-19.00.58 0 (2, 4)
# quesadilla_mit-eval 123 (8, 4)
# quesadilla_mit-eval 2 (2, 4)
# quesadilla_mit-eval 2 (2, 4)
# quesadilla_onplate_hallway 2 (1, 4)
# rolled_kitchen_lightson 2 (1, 4)
# rolled_kitchen_lightson2 1 (1, 4)
# rolled_nursingroom_lightson 0 (1, 4)
# rolled_nursingroom_lightson2 1 (1, 4)
# rolled_office_lightsoff 1 (1, 4)
# rolled_office_lightson 1 (1, 4)
# rolled_printerroom_lightsoff 0 (1, 4)
# rolled_toothpick_kitchen_lightsoff 0 (1, 4)
# rolled_toothpick_kitchen_lightson 0 (1, 4)
# rolled_toothpick_nursing_lightsoff 0 (1, 4)
# rolled_toothpick_nursing_lightson 0 (1, 4)
# rolled_toothpick_office_lightsoff 0 (1, 4)
# rolled_toothpick_office_lightson 0 (1, 4)
# rolled_toothpick_orange_booth_lightsoff 0 (1, 4)
# rolled_toothpick_orange_booth_lightson 0 (1, 4)
# rolled_toothpick_printer 0 (1, 4)
# rolled_toothpick_staircase 0 (1, 4)
# rolled_toothpick_window 0 (1, 4)
# sliced_pinwheel_kitchen_lightsoff 0 (1, 4)
# sliced_pinwheel_kitchen_lightson 0 (1, 4)
# sliced_pinwheel_nursing_lightsoff 0 (1, 4)
# sliced_pinwheel_nursing_lightson 0 (1, 4)
# sliced_pinwheel_office_lightsoff 0 (1, 4)
# sliced_pinwheel_office_lightson 0 (1, 4)
# sliced_pinwheel_orange_booth_lightsoff 0 (1, 4)
# sliced_pinwheel_orange_booth_lightson 0 (1, 4)
# sliced_pinwheel_printer 0 (1, 4)
# sliced_pinwheel_staircase 0 (1, 4)
# sliced_pinwheel_window 0 (1, 4)
# sliced_quesadilla_kitchen_lightsoff 5 (1, 4)
# sliced_quesadilla_kitchen_lightson 0 (1, 4)
# sliced_quesadilla_nursing_lightsoff 8 (1, 4)
# sliced_quesadilla_nursing_lightson 8 (1, 4)
# sliced_quesadilla_office_lightsoff 2 (1, 4)
# sliced_quesadilla_office_lightson 0 (1, 4)
# sliced_quesadilla_printer 0 (1, 4)
# sliced_quesadilla_window 1 (1, 4)
# tortilla_nutella_banana_kitchen_lightoff 0 (1, 4)
# tortilla_nutella_banana_kitchen_lighton 0 (1, 4)
# tortilla_nutella_banana_nursing_lightoff 0 (1, 4)
# tortilla_nutella_banana_nursing_lighton 0 (1, 4)
# tortilla_nutella_banana_office_lightoff 0 (1, 4)
# tortilla_nutella_banana_office_lighton 0 (1, 4)
# tortilla_nutella_banana_orange_booth_lightsoff 0 (1, 4)
# tortilla_nutella_banana_orange_booth_lightson 11 (1, 4)
# tortilla_nutella_banana_printer_room 0 (1, 4)
# tortilla_nutella_banana_staircase 3 (1, 4)
# tortilla_nutella_banana_window 0 (1, 4)
# tortilla_nutella_kitchen_lightoff 0 (1, 4)
# tortilla_nutella_kitchen_lighton 0 (1, 4)
# tortilla_nutella_nursing_lightoff 0 (1, 4)
# tortilla_nutella_nursing_lighton 0 (1, 4)
# tortilla_nutella_office_lightoff 0 (1, 4)
# tortilla_nutella_office_lighton 0 (1, 4)
# tortilla_nutella_orange_booth_lightsoff 0 (1, 4)
# tortilla_nutella_orange_booth_lightson 0 (1, 4)
# tortilla_nutella_printer_room 0 (1, 4)
# tortilla_nutella_staircase 0 (1, 4)
# tortilla_nutella_window 0 (1, 4)
# set()
# folded_kitchen_lightsoff 0 (1, 4)
# folded_kitchen_lightson 0 (1, 4)
# folded_nursing_lightsoff 0 (1, 4)
# folded_nursing_lightson 0 (1, 4)
# folded_office_lightsoff 0 (1, 4)
# folded_office_lightson 0 (1, 4)
# folded_orange_booth_lightsoff 0 (1, 4)
# folded_orange_booth_lightson 0 (1, 4)
# folded_printer 0 (1, 4)
# folded_staircase 0 (1, 4)
# folded_window 0 (1, 4)
# oatmeal_2023.06.16-20.08.08 0 (9, 4)
# oatmeal_2023.06.16-20.18.26 0 (9, 4)
# oatmeal_2023.06.16-20.33.26 0 (9, 4)
# oatmeal_2023.06.30-20.10.42 0 (8, 4)
# oatmeal_2023.06.30-20.21.07 0 (8, 4)
# oatmeal_mit-eval 0 (9, 4)
# on_plate_pinwheel_office_lightson 0 (1, 4)
# on_plate_quesadilla_kitchen_lightson 1 (1, 4)
# on_plate_quesadilla_nursing_lightsoff 1 (1, 4)
# on_plate_quesadilla_nursing_lightson 1 (1, 4)
# on_plate_quesadilla_office_lightsoff 1 (1, 4)
# on_plate_quesadilla_office_lightson 1 (1, 4)
# on_plate_quesadilla_printer 1 (1, 4)
# package_kitchen_lightsoff 0 (1, 4)
# package_kitchen_lightson 0 (1, 4)
# package_nursingroom_lightsoff 0 (1, 4)
# package_nursingroom_lightson 2 (1, 4)
# package_office_lightsoff 0 (1, 4)
# package_office_lightson 0 (1, 4)
# package_orangebooth_lightson 0 (1, 4)
# package_stairwell_as-is 20 (1, 4)
# package_window_lightson 20 (1, 4)
# pb_jelly_kitchen_lightsoff 1 (1, 4)
# pb_jelly_office_lightsoff 2 (1, 4)
# pb_jelly_printerroom_lightsoff 1 (1, 4)
# peanut-butter_kitchen_lightsoff 0 (1, 4)
# peanut-butter_kitchen_lightson 0 (1, 4)
# peanut-butter_nursingroom_lightsoff 0 (1, 4)
# peanut-butter_nursingroom_lightson 0 (1, 4)
# peanut-butter_office_lightsoff 0 (1, 4)
# peanut-butter_orangeroom_lightsoff 0 (1, 4)
# peanut-butter_orangeroom_lightson 0 (1, 4)
# peanut-butter_printerroom_lightsoff 0 (1, 4)
# peanut-butter_stairwell_as-is 0 (1, 4)
# peanut-butter_window_lightson 0 (1, 4)
# pinwheels_2023.03.01-21.35.14 0 (13, 4)
# pinwheels_2023.03.01-21.35.14 0 (1, 4)
# pinwheels_2023.03.02-22.56.36 1 (18, 4)
# pinwheels_2023.03.02-22.56.36 0 (3, 4)
# pinwheels_2023.03.02-22.56.36 0 (5, 4)
# pinwheels_2023.03.08-17.46.28 9 (17, 4)
# pinwheels_2023.03.08-17.46.28 9 (3, 4)
# pinwheels_2023.03.08-17.46.28 9 (5, 4)
# pinwheels_2023.03.30-16.38.48 4 (18, 4)
# pinwheels_2023.03.30-16.38.48 4 (3, 4)
# pinwheels_2023.03.30-16.50.36 0 (18, 4)
# pinwheels_2023.03.30-16.50.36 0 (3, 4)
# pinwheels_2023.04.03-19.38.08 0 (18, 4)
# pinwheels_2023.04.03-19.38.08 0 (3, 4)
# pinwheels_2023.04.04-18.33.59 0 (18, 4)
# pinwheels_2023.04.04-18.33.59 0 (3, 4)
# pinwheels_2023.04.04-18.33.59 0 (5, 4)
# pinwheels_2023.04.04-19.50.02 0 (18, 4)
# pinwheels_2023.04.04-19.50.02 0 (3, 4)
# pinwheels_mit-eval 91 (18, 4)
# pinwheels_mit-eval 0 (3, 4)
# pinwheels_mit-eval 0 (5, 4)
# plain_kitchen_lightsoff 0 (1, 4)
# plain_kitchen_lightson 0 (1, 4)
# plain_nursingroom_lightsoff 0 (1, 4)
# plain_office_lightson 0 (1, 4)
# plain_orangebooth_lightsoff 0 (1, 4)
# plain_printerroom_lightsoff 0 (1, 4)
# plain_stairwell_as-is 0 (1, 4)
# plain_window_lightson 0 (1, 4)
# quesadilla_2023.06.16-18.53.43 1 (12, 4)
# quesadilla_2023.06.16-18.53.43 0 (3, 4)
# quesadilla_2023.06.16-18.53.43 0 (2, 4)
# quesadilla_2023.06.16-18.57.48 1 (12, 4)
# quesadilla_2023.06.16-18.57.48 0 (3, 4)
# quesadilla_2023.06.16-18.57.48 0 (2, 4)
# quesadilla_2023.06.16-19.00.58 1 (12, 4)
# quesadilla_2023.06.16-19.00.58 0 (3, 4)
# quesadilla_2023.06.16-19.00.58 0 (2, 4)
# quesadilla_mit-eval 123 (11, 4)
# quesadilla_mit-eval 2 (2, 4)
# quesadilla_mit-eval 2 (2, 4)
# rolled_kitchen_lightson 2 (1, 4)
# rolled_printerroom_lightsoff 0 (1, 4)
# sliced_pinwheel_office_lightson 0 (1, 4)
# sliced_pinwheel_window 0 (1, 4)
# sliced_quesadilla_kitchen_lightsoff 5 (1, 4)
# sliced_quesadilla_kitchen_lightson 0 (1, 4)
# sliced_quesadilla_nursing_lightsoff 8 (1, 4)
# sliced_quesadilla_office_lightsoff 2 (1, 4)
# sliced_quesadilla_office_lightson 0 (1, 4)
# sliced_quesadilla_printer 0 (1, 4)
# sliced_quesadilla_window 1 (1, 4)
# tortilla_nutella_banana_kitchen_lightoff 0 (1, 4)
# tortilla_nutella_banana_kitchen_lighton 0 (1, 4)
# tortilla_nutella_banana_nursing_lightoff 0 (1, 4)
# tortilla_nutella_banana_nursing_lighton 0 (1, 4)
# tortilla_nutella_banana_office_lightoff 0 (1, 4)
# tortilla_nutella_banana_office_lighton 0 (1, 4)
# tortilla_nutella_banana_printer_room 0 (1, 4)
# tortilla_nutella_kitchen_lightoff 0 (1, 4)
# tortilla_nutella_kitchen_lighton 0 (1, 4)
# tortilla_nutella_nursing_lightoff 0 (1, 4)
# tortilla_nutella_nursing_lighton 0 (1, 4)
# tortilla_nutella_office_lighton 0 (1, 4)
# Found 147 files ['/datasets/static_eval/embeddings/detections_tracker/package_office_lightsoff.MOV/clip/13.npz']
# loading data...:   0%|          | 0/147 [00:00<?, ?it/s]
# Skipping: package_office_lightsoff: 13
# super_simple {'package_office_lightsoff'}
# super_simple {0}
# full {'package_office_lightsoff'}
# full {0}
# loading data...:   1%|▏         | 2/147 [00:22<27:11, 11.25s/it]
# using package_office_lightsoff.0 (24708, 3) {'full', 'super_simple'} (24708, 512)
# super_simple {'rolled_nursingroom_lightson2'}
# super_simple {0}
# loading data...:   2%|▏         | 3/147 [00:33<26:24, 11.01s/it]
# using rolled_nursingroom_lightson2.0 (22296, 2) {'super_simple'} (22296, 512)
# super_simple {'rolled_nursingroom_lightson2'}
# super_simple {1}
# loading data...:   3%|▎         | 4/147 [00:44<26:10, 10.98s/it]
# using rolled_nursingroom_lightson2.1 (22416, 2) {'super_simple'} (22416, 512)
# Skipping: rolled_nursingroom_lightson2: 3
# super_simple {'peanut-butter_orangeroom_lightsoff'}
# super_simple {0}
# full {'peanut-butter_orangeroom_lightsoff'}
# full {0}
# loading data...:   4%|▍         | 6/147 [01:06<25:51, 11.00s/it]
# using peanut-butter_orangeroom_lightsoff.0 (23496, 3) {'full', 'super_simple'} (23496, 512)
# super_simple {'plain_kitchen_lightsoff'}
# super_simple {0}
# full {'plain_kitchen_lightsoff'}
# full {0}
# loading data...:   5%|▍         | 7/147 [01:25<30:59, 13.28s/it]
# using plain_kitchen_lightsoff.0 (20520, 3) {'full', 'super_simple'} (20520, 512)
# Skipping: pb_jelly_kitchen_lightsoff: 7
# super_simple {'pb_jelly_kitchen_lightsoff'}
# super_simple {0}
# full {'pb_jelly_kitchen_lightsoff'}
# full {0}
# loading data...:   6%|▌         | 9/147 [01:46<27:46, 12.07s/it]
# using pb_jelly_kitchen_lightsoff.0 (22020, 3) {'full', 'super_simple'} (22020, 512)
# super_simple {'pb_jelly_kitchen_lightsoff'}
# super_simple {1}
# full {'pb_jelly_kitchen_lightsoff'}
# full {1}
# loading data...:   7%|▋         | 10/147 [02:06<31:40, 13.87s/it]
# using pb_jelly_kitchen_lightsoff.1 (22020, 3) {'full', 'super_simple'} (22020, 512)
# Skipping: pb_jelly_kitchen_lightsoff: 6
# super_simple {'tortilla_nutella_kitchen_lightoff'}
# super_simple {0}
# full {'tortilla_nutella_kitchen_lightoff'}
# full {0}
# loading data...:   8%|▊         | 12/147 [02:29<29:04, 12.92s/it]
# using tortilla_nutella_kitchen_lightoff.0 (22788, 3) {'full', 'super_simple'} (22788, 512)
# super_simple {'tortilla_nutella_banana_window'}
# super_simple {0}
# loading data...:   9%|▉         | 13/147 [02:44<29:43, 13.31s/it]
# using tortilla_nutella_banana_window.0 (31884, 2) {'super_simple'} (31884, 512)
# Skipping: package_stairwell_as-is: 4
# super_simple {'package_stairwell_as-is'}
# super_simple {0}
# full {'package_stairwell_as-is'}
# full {0}
# loading data...:  10%|█         | 15/147 [03:01<25:10, 11.44s/it]
# using package_stairwell_as-is.0 (18984, 3) {'full', 'super_simple'} (18984, 512)
# super_simple {'package_stairwell_as-is'}
# super_simple {20}
# full {'package_stairwell_as-is'}
# full {20}
# loading data...:  11%|█         | 16/147 [03:02<20:05,  9.20s/it]
# using package_stairwell_as-is.20 (1248, 3) {'full', 'super_simple'} (1248, 512)
# super_simple {'tortilla_nutella_kitchen_lighton'}
# super_simple {0}
# full {'tortilla_nutella_kitchen_lighton'}
# full {0}
# loading data...:  12%|█▏        | 17/147 [03:30<29:36, 13.66s/it]
# using tortilla_nutella_kitchen_lighton.0 (30096, 3) {'full', 'super_simple'} (30096, 512)
# Skipping: tortilla_nutella_kitchen_lighton: 1
# super_simple {'tortilla_nutella_banana_office_lightoff'}
# super_simple {0}
# full {'tortilla_nutella_banana_office_lightoff'}
# full {0}
# loading data...:  18%|█▊        | 26/147 [03:49<08:01,  3.98s/it]
# using tortilla_nutella_banana_office_lightoff.0 (20808, 3) {'full', 'super_simple'} (20808, 512)
# Skipping: on_plate_quesadilla_printer: 4
# Skipping: on_plate_quesadilla_printer: 2
# Skipping: on_plate_quesadilla_printer: 9
# Skipping: on_plate_quesadilla_printer: 0
# Skipping: on_plate_quesadilla_printer: 16
# Skipping: on_plate_quesadilla_printer: 1
# Skipping: on_plate_quesadilla_printer: 10
# super_simple {'tortilla_nutella_banana_office_lighton'}
# super_simple {0}
# full {'tortilla_nutella_banana_office_lighton'}
# full {0}
# loading data...:  20%|█▉        | 29/147 [04:06<08:13,  4.18s/it]
# using tortilla_nutella_banana_office_lighton.0 (18288, 3) {'full', 'super_simple'} (18288, 512)
# Skipping: package_window_lightson: 2
# Skipping: package_window_lightson: 0
# Skipping: package_window_lightson: 37
# loading data...:  20%|█▉        | 29/147 [04:07<08:13,  4.18s/it]
# super_simple {'tortilla_nutella_banana_nursing_lightoff'}
# super_simple {0}
# full {'tortilla_nutella_banana_nursing_lightoff'}
# full {0}
# loading data...:  21%|██        | 31/147 [04:28<11:36,  6.00s/it]
# using tortilla_nutella_banana_nursing_lightoff.0 (23880, 3) {'full', 'super_simple'} (23880, 512)
# Skipping: sliced_quesadilla_nursing_lightsoff: 2
# super_simple {'sliced_quesadilla_nursing_lightsoff'}
# super_simple {0}
# full {'sliced_quesadilla_nursing_lightsoff'}
# full {0}
# loading data...:  22%|██▏       | 33/147 [04:48<13:22,  7.04s/it]
# using sliced_quesadilla_nursing_lightsoff.0 (21228, 3) {'full', 'super_simple'} (21228, 512)
# super_simple {'sliced_quesadilla_nursing_lightsoff'}
# super_simple {8}
# full {'sliced_quesadilla_nursing_lightsoff'}
# full {8}
# loading data...:  23%|██▎       | 34/147 [04:50<11:47,  6.26s/it]
# using sliced_quesadilla_nursing_lightsoff.8 (2520, 3) {'full', 'super_simple'} (2520, 512)
# super_simple {'sliced_quesadilla_nursing_lightsoff'}
# super_simple {1}
# full {'sliced_quesadilla_nursing_lightsoff'}
# full {1}
# loading data...:  23%|██▎       | 34/147 [05:00<11:47,  6.26s/it]
# using sliced_quesadilla_nursing_lightsoff.1 (10836, 3) {'full', 'super_simple'} (10836, 512)
# super_simple {'plain_nursingroom_lightson'}
# super_simple {0}
# loading data...:  24%|██▍       | 36/147 [05:11<13:56,  7.54s/it]
# using plain_nursingroom_lightson.0 (22236, 2) {'super_simple'} (22236, 512)
# super_simple {'peanut-butter_office_lightsoff'}
# super_simple {0}
# full {'peanut-butter_office_lightsoff'}
# full {0}
# loading data...:  25%|██▌       | 37/147 [05:32<18:20, 10.01s/it]
# using peanut-butter_office_lightsoff.0 (21768, 3) {'full', 'super_simple'} (21768, 512)
# Skipping: pb_jelly_nursingroom_lightson: 5
# super_simple {'pb_jelly_nursingroom_lightson'}
# super_simple {0}
# loading data...:  27%|██▋       | 39/147 [05:42<15:00,  8.34s/it]
# using pb_jelly_nursingroom_lightson.0 (22080, 2) {'super_simple'} (22080, 512)
# super_simple {'pb_jelly_nursingroom_lightson'}
# super_simple {1}
# loading data...:  27%|██▋       | 40/147 [05:52<15:36,  8.75s/it]
# using pb_jelly_nursingroom_lightson.1 (22080, 2) {'super_simple'} (22080, 512)
# Skipping: tortilla_nutella_office_lighton: 5
# super_simple {'tortilla_nutella_office_lighton'}
# super_simple {0}
# full {'tortilla_nutella_office_lighton'}
# full {0}
# loading data...:  29%|██▊       | 42/147 [06:21<18:42, 10.69s/it]
# using tortilla_nutella_office_lighton.0 (30744, 3) {'full', 'super_simple'} (30744, 512)
# super_simple {'tortilla_nutella_nursing_lightoff'}
# super_simple {0}
# full {'tortilla_nutella_nursing_lightoff'}
# full {0}
# loading data...:  29%|██▉       | 43/147 [06:44<23:03, 13.30s/it]
# using tortilla_nutella_nursing_lightoff.0 (25416, 3) {'full', 'super_simple'} (25416, 512)
# Skipping: package_printerroom_lightson: 9
# super_simple {'package_printerroom_lightson'}
# super_simple {0}
# loading data...:  33%|███▎      | 49/147 [06:56<08:25,  5.16s/it]
# using package_printerroom_lightson.0 (25224, 2) {'super_simple'} (25224, 512)
# Skipping: rolled_office_lightsoff: 9
# Skipping: rolled_office_lightsoff: 0
# Skipping: rolled_office_lightsoff: 1
# Skipping: rolled_office_lightsoff: 3
# Skipping: plain_kitchen_lightson: 2
# super_simple {'plain_kitchen_lightson'}
# super_simple {0}
# full {'plain_kitchen_lightson'}
# full {0}
# loading data...:  35%|███▍      | 51/147 [07:18<10:47,  6.75s/it]
# using plain_kitchen_lightson.0 (23328, 3) {'full', 'super_simple'} (23328, 512)
# super_simple {'plain_window_lightson'}
# super_simple {0}
# full {'plain_window_lightson'}
# full {0}
# loading data...:  35%|███▌      | 52/147 [07:49<16:46, 10.59s/it]
# using plain_window_lightson.0 (34044, 3) {'full', 'super_simple'} (34044, 512)
# super_simple {'peanut-butter_printerroom_lightsoff'}
# super_simple {0}
# full {'peanut-butter_printerroom_lightsoff'}
# full {0}
# loading data...:  36%|███▌      | 53/147 [08:08<19:13, 12.28s/it]
# using peanut-butter_printerroom_lightsoff.0 (21504, 3) {'full', 'super_simple'} (21504, 512)
# super_simple {'tortilla_nutella_orange_booth_lightsoff'}
# super_simple {0}
# loading data...:  37%|███▋      | 54/147 [08:21<19:05, 12.32s/it]
# using tortilla_nutella_orange_booth_lightsoff.0 (25500, 2) {'super_simple'} (25500, 512)
# super_simple {'tortilla_nutella_printer_room'}
# super_simple {0}
# loading data...:  37%|███▋      | 55/147 [08:32<18:19, 11.95s/it]
# using tortilla_nutella_printer_room.0 (21960, 2) {'super_simple'} (21960, 512)
# super_simple {'plain_orangebooth_lightson'}
# super_simple {0}
# loading data...:  38%|███▊      | 56/147 [08:45<18:47, 12.38s/it]
# using plain_orangebooth_lightson.0 (28092, 2) {'super_simple'} (28092, 512)
# super_simple {'tortilla_nutella_window'}
# super_simple {0}
# loading data...:  39%|███▉      | 57/147 [08:59<18:55, 12.61s/it]
# using tortilla_nutella_window.0 (27084, 2) {'super_simple'} (27084, 512)
# super_simple {'tortilla_nutella_banana_nursing_lighton'}
# super_simple {0}
# full {'tortilla_nutella_banana_nursing_lighton'}
# full {0}
# loading data...:  39%|███▉      | 58/147 [09:16<20:27, 13.80s/it]
# using tortilla_nutella_banana_nursing_lighton.0 (16764, 3) {'full', 'super_simple'} (16764, 512)
# Skipping: tortilla_nutella_banana_nursing_lighton: 1
# super_simple {'tortilla_nutella_staircase'}
# super_simple {0}
# loading data...:  41%|████      | 60/147 [09:27<14:59, 10.34s/it]
# using tortilla_nutella_staircase.0 (24072, 2) {'super_simple'} (24072, 512)
# super_simple {'tortilla_nutella_banana_printer_room'}
# super_simple {0}
# full {'tortilla_nutella_banana_printer_room'}
# full {0}
# loading data...:  41%|████▏     | 61/147 [09:48<18:12, 12.70s/it]
# using tortilla_nutella_banana_printer_room.0 (21276, 3) {'full', 'super_simple'} (21276, 512)
# super_simple {'tortilla_nutella_banana_kitchen_lighton'}
# super_simple {0}
# full {'tortilla_nutella_banana_kitchen_lighton'}
# full {0}
# loading data...:  42%|████▏     | 62/147 [10:06<19:55, 14.07s/it]
# using tortilla_nutella_banana_kitchen_lighton.0 (20292, 3) {'full', 'super_simple'} (20292, 512)
# super_simple {'package_nursingroom_lightson'}
# super_simple {0}
# full {'package_nursingroom_lightson'}
# full {0}
# loading data...:  43%|████▎     | 63/147 [10:28<22:40, 16.19s/it]
# using package_nursingroom_lightson.0 (23976, 3) {'full', 'super_simple'} (23976, 512)
# Skipping: package_nursingroom_lightson: 3
# Skipping: pb_jelly_office_lightson: 13
# Skipping: pb_jelly_office_lightson: 0
# super_simple {'pb_jelly_office_lightson'}
# super_simple {1}
# loading data...:  46%|████▌     | 67/147 [10:38<10:41,  8.02s/it]
# using pb_jelly_office_lightson.1 (22284, 2) {'super_simple'} (22284, 512)
# super_simple {'rolled_nursingroom_lightson'}
# super_simple {0}
# loading data...:  48%|████▊     | 71/147 [10:48<06:03,  4.78s/it]
# using rolled_nursingroom_lightson.0 (21360, 2) {'super_simple'} (21360, 512)
# Skipping: rolled_nursingroom_lightson: 1
# Skipping: sliced_quesadilla_nursing_lightson: 0
# Skipping: sliced_quesadilla_nursing_lightson: 1
# Skipping: sliced_quesadilla_nursing_lightson: 3
# super_simple {'sliced_quesadilla_kitchen_lightsoff'}
# super_simple {5}
# full {'sliced_quesadilla_kitchen_lightsoff'}
# full {5}
# loading data...:  48%|████▊     | 71/147 [10:50<06:03,  4.78s/it]
# using sliced_quesadilla_kitchen_lightsoff.5 (1728, 3) {'full', 'super_simple'} (1728, 512)
# super_simple {'sliced_quesadilla_kitchen_lightsoff'}
# super_simple {0}
# full {'sliced_quesadilla_kitchen_lightsoff'}
# full {0}
# loading data...:  50%|█████     | 74/147 [11:10<06:52,  5.66s/it]
# using sliced_quesadilla_kitchen_lightsoff.0 (21528, 3) {'full', 'super_simple'} (21528, 512)
# Skipping: sliced_quesadilla_kitchen_lightsoff: 8
# super_simple {'sliced_quesadilla_kitchen_lightsoff'}
# super_simple {1}
# full {'sliced_quesadilla_kitchen_lightsoff'}
# full {1}
# loading data...:  52%|█████▏    | 76/147 [11:11<05:07,  4.33s/it]
# using sliced_quesadilla_kitchen_lightsoff.1 (1452, 3) {'full', 'super_simple'} (1452, 512)
# super_simple {'package_nursingroom_lightsoff'}
# super_simple {0}
# full {'package_nursingroom_lightsoff'}
# full {0}
# loading data...:  53%|█████▎    | 78/147 [11:24<05:37,  4.89s/it]
# using package_nursingroom_lightsoff.0 (14064, 3) {'full', 'super_simple'} (14064, 512)
# Skipping: package_nursingroom_lightsoff: 3
# Skipping: sliced_pinwheel_kitchen_lightsoff: 0
# super_simple {'pb_jelly_office_lightsoff'}
# super_simple {2}
# full {'pb_jelly_office_lightsoff'}
# full {2}
# loading data...:  54%|█████▍    | 80/147 [11:41<06:36,  5.92s/it]
# using pb_jelly_office_lightsoff.2 (17820, 3) {'full', 'super_simple'} (17820, 512)
# super_simple {'pb_jelly_office_lightsoff'}
# super_simple {0}
# full {'pb_jelly_office_lightsoff'}
# full {0}
# loading data...:  55%|█████▌    | 81/147 [12:02<09:13,  8.39s/it]
# using pb_jelly_office_lightsoff.0 (22500, 3) {'full', 'super_simple'} (22500, 512)
# Skipping: rolled_office_lightson: 0
# Skipping: rolled_office_lightson: 1
# super_simple {'tortilla_nutella_banana_kitchen_lightoff'}
# super_simple {0}
# full {'tortilla_nutella_banana_kitchen_lightoff'}
# full {0}
# loading data...:  57%|█████▋    | 84/147 [12:22<08:06,  7.72s/it]
# using tortilla_nutella_banana_kitchen_lightoff.0 (21348, 3) {'full', 'super_simple'} (21348, 512)
# super_simple {'peanut-butter_window_lightson'}
# super_simple {0}
# full {'peanut-butter_window_lightson'}
# full {0}
# loading data...:  58%|█████▊    | 85/147 [12:43<10:20, 10.00s/it]
# using peanut-butter_window_lightson.0 (22452, 3) {'full', 'super_simple'} (22452, 512)
# super_simple {'pb_jelly_nursingroom_lightsoff'}
# super_simple {2}
# loading data...:  59%|█████▊    | 86/147 [12:47<08:58,  8.83s/it]
# using pb_jelly_nursingroom_lightsoff.2 (7908, 2) {'super_simple'} (7908, 512)
# super_simple {'pb_jelly_nursingroom_lightsoff'}
# super_simple {0}
# loading data...:  59%|█████▊    | 86/147 [12:58<08:58,  8.83s/it]
# using pb_jelly_nursingroom_lightsoff.0 (23388, 2) {'super_simple'} (23388, 512)
# super_simple {'pb_jelly_nursingroom_lightsoff'}
# super_simple {1}
# loading data...:  60%|█████▉    | 88/147 [13:09<09:26,  9.60s/it]
# using pb_jelly_nursingroom_lightsoff.1 (23388, 2) {'super_simple'} (23388, 512)
# super_simple {'peanut-butter_nursingroom_lightsoff'}
# super_simple {0}
# full {'peanut-butter_nursingroom_lightsoff'}
# full {0}
# loading data...:  61%|██████    | 89/147 [13:30<11:30, 11.91s/it]
# using peanut-butter_nursingroom_lightsoff.0 (22872, 3) {'full', 'super_simple'} (22872, 512)
# super_simple {'rolled_printerroom_lightsoff'}
# super_simple {0}
# full {'rolled_printerroom_lightsoff'}
# full {0}
# loading data...:  61%|██████    | 90/147 [13:38<10:21, 10.91s/it]
# using rolled_printerroom_lightsoff.0 (8052, 3) {'full', 'super_simple'} (8052, 512)
# Skipping: pb_jelly_kitchen_lightson: 4
# Skipping: pb_jelly_kitchen_lightson: 9
# super_simple {'pb_jelly_kitchen_lightson'}
# super_simple {0}
# loading data...:  63%|██████▎   | 93/147 [13:48<06:29,  7.21s/it]
# using pb_jelly_kitchen_lightson.0 (21564, 2) {'super_simple'} (21564, 512)
# super_simple {'pb_jelly_kitchen_lightson'}
# super_simple {1}
# loading data...:  64%|██████▍   | 94/147 [13:58<06:51,  7.77s/it]
# using pb_jelly_kitchen_lightson.1 (21564, 2) {'super_simple'} (21564, 512)
# Skipping: pb_jelly_kitchen_lightson: 10
# Skipping: pb_jelly_kitchen_lightson: 3
# super_simple {'tortilla_nutella_banana_staircase'}
# super_simple {0}
# loading data...:  66%|██████▌   | 97/147 [14:11<05:10,  6.21s/it]
# using tortilla_nutella_banana_staircase.0 (27384, 2) {'super_simple'} (27384, 512)
# super_simple {'tortilla_nutella_banana_staircase'}
# super_simple {3}
# loading data...:  67%|██████▋   | 98/147 [14:12<04:24,  5.39s/it]
# using tortilla_nutella_banana_staircase.3 (3264, 2) {'super_simple'} (3264, 512)
# super_simple {'pb_jelly_printerroom_lightsoff'}
# super_simple {0}
# full {'pb_jelly_printerroom_lightsoff'}
# full {0}
# loading data...:  67%|██████▋   | 99/147 [14:29<06:03,  7.57s/it]
# using pb_jelly_printerroom_lightsoff.0 (17616, 3) {'full', 'super_simple'} (17616, 512)
# super_simple {'pb_jelly_printerroom_lightsoff'}
# super_simple {1}
# full {'pb_jelly_printerroom_lightsoff'}
# full {1}
# loading data...:  68%|██████▊   | 100/147 [14:46<07:40,  9.79s/it]
# using pb_jelly_printerroom_lightsoff.1 (17616, 3) {'full', 'super_simple'} (17616, 512)
# super_simple {'sliced_quesadilla_kitchen_lightson'}
# super_simple {0}
# full {'sliced_quesadilla_kitchen_lightson'}
# full {0}
# loading data...:  69%|██████▊   | 101/147 [15:06<09:20, 12.19s/it]
# using sliced_quesadilla_kitchen_lightson.0 (21384, 3) {'full', 'super_simple'} (21384, 512)
# Skipping: sliced_quesadilla_kitchen_lightson: 1
# super_simple {'tortilla_nutella_banana_orange_booth_lightson'}
# super_simple {11}
# loading data...:  70%|███████   | 103/147 [15:11<06:01,  8.22s/it]
# using tortilla_nutella_banana_orange_booth_lightson.11 (10404, 2) {'super_simple'} (10404, 512)
# super_simple {'tortilla_nutella_banana_orange_booth_lightson'}
# super_simple {0}
# loading data...:  71%|███████   | 104/147 [15:20<05:59,  8.36s/it]
# using tortilla_nutella_banana_orange_booth_lightson.0 (18792, 2) {'super_simple'} (18792, 512)
# super_simple {'rolled_toothpick_nursing_lightson'}
# super_simple {0}
# loading data...:  71%|███████▏  | 105/147 [15:26<05:31,  7.90s/it]
# using rolled_toothpick_nursing_lightson.0 (13764, 2) {'super_simple'} (13764, 512)
# Skipping: package_kitchen_lightson: 2
# loading data...:  73%|███████▎  | 107/147 [15:27<03:12,  4.81s/it]
# Skipping: package_kitchen_lightson: 0
# super_simple {'tortilla_nutella_nursing_lighton'}
# super_simple {0}
# full {'tortilla_nutella_nursing_lighton'}
# full {0}
# loading data...:  73%|███████▎  | 108/147 [15:52<06:07,  9.41s/it]
# using tortilla_nutella_nursing_lighton.0 (27204, 3) {'full', 'super_simple'} (27204, 512)
# loading data...:  74%|███████▍  | 109/147 [15:52<04:34,  7.23s/it]
# Skipping: package_orangebooth_lightson: 11
# Skipping: package_orangebooth_lightson: 19
# loading data...:  74%|███████▍  | 109/147 [15:53<04:34,  7.23s/it]
# super_simple {'package_orangebooth_lightson'}
# super_simple {0}
# full {'package_orangebooth_lightson'}
# full {0}
# loading data...:  76%|███████▌  | 111/147 [16:13<05:03,  8.43s/it]
# using package_orangebooth_lightson.0 (21408, 3) {'full', 'super_simple'} (21408, 512)
# loading data...:  76%|███████▌  | 112/147 [16:13<03:52,  6.64s/it]
# Skipping: package_orangebooth_lightson: 3
# Skipping: sliced_pinwheel_office_lightson: 0
# loading data...:  76%|███████▌  | 112/147 [16:13<03:52,  6.64s/it]
# super_simple {'package_office_lightson'}
# super_simple {0}
# full {'package_office_lightson'}
# full {0}
# loading data...:  78%|███████▊  | 114/147 [16:34<04:28,  8.13s/it]
# using package_office_lightson.0 (21972, 3) {'full', 'super_simple'} (21972, 512)
# loading data...:  79%|███████▉  | 116/147 [16:35<02:33,  4.95s/it]
# Skipping: rolled_toothpick_kitchen_lightson: 2
# Skipping: rolled_toothpick_kitchen_lightson: 1
# loading data...:  79%|███████▉  | 116/147 [16:35<02:33,  4.95s/it]
# super_simple {'plain_orangebooth_lightsoff'}
# super_simple {0}
# full {'plain_orangebooth_lightsoff'}
# full {0}
# loading data...:  80%|███████▉  | 117/147 [16:59<04:58,  9.94s/it]
# using plain_orangebooth_lightsoff.0 (26604, 3) {'full', 'super_simple'} (26604, 512)
# loading data...:  80%|███████▉  | 117/147 [17:00<04:58,  9.94s/it]
# super_simple {'tortilla_nutella_office_lightoff'}
# super_simple {0}
# loading data...:  80%|████████  | 118/147 [17:07<04:30,  9.33s/it]
# using tortilla_nutella_office_lightoff.0 (15288, 2) {'super_simple'} (15288, 512)
# super_simple {'tortilla_nutella_orange_booth_lightson'}
# super_simple {0}
# loading data...:  81%|████████  | 119/147 [17:19<04:42, 10.08s/it]
# using tortilla_nutella_orange_booth_lightson.0 (25236, 2) {'super_simple'} (25236, 512)
# loading data...:  81%|████████  | 119/147 [17:19<04:42, 10.08s/it]
# super_simple {'package_orangebooth_lightsoff'}
# super_simple {5}
# loading data...:  82%|████████▏ | 120/147 [17:30<04:39, 10.35s/it]
# using package_orangebooth_lightsoff.5 (23208, 2) {'super_simple'} (23208, 512)
# loading data...:  82%|████████▏ | 120/147 [17:30<04:39, 10.35s/it]
# super_simple {'package_orangebooth_lightsoff'}
# super_simple {0}
# loading data...:  82%|████████▏ | 121/147 [17:41<04:35, 10.60s/it]
# using package_orangebooth_lightsoff.0 (23676, 2) {'super_simple'} (23676, 512)
# Skipping: rolled_kitchen_lightson2: 7
# loading data...:  82%|████████▏ | 121/147 [17:41<04:35, 10.60s/it]
# super_simple {'rolled_kitchen_lightson2'}
# super_simple {0}
# loading data...:  84%|████████▍ | 124/147 [17:52<02:22,  6.19s/it]
# using rolled_kitchen_lightson2.0 (21660, 2) {'super_simple'} (21660, 512)
# Skipping: rolled_kitchen_lightson2: 8
# loading data...:  84%|████████▍ | 124/147 [17:52<02:22,  6.19s/it]
# super_simple {'rolled_kitchen_lightson2'}
# super_simple {1}
# loading data...:  85%|████████▌ | 125/147 [18:02<02:38,  7.20s/it]
# using rolled_kitchen_lightson2.1 (21300, 2) {'super_simple'} (21300, 512)
# loading data...:  85%|████████▌ | 125/147 [18:02<02:38,  7.20s/it]
# super_simple {'peanut-butter_stairwell_as-is'}
# super_simple {0}
# full {'peanut-butter_stairwell_as-is'}
# full {0}
# loading data...:  86%|████████▌ | 126/147 [18:32<04:43, 13.50s/it]
# using peanut-butter_stairwell_as-is.0 (31716, 3) {'full', 'super_simple'} (31716, 512)
# loading data...:  86%|████████▋ | 127/147 [18:33<03:17,  9.86s/it]
# Skipping: sliced_quesadilla_office_lightson: 9
# super_simple {'sliced_quesadilla_office_lightson'}
# super_simple {0}
# full {'sliced_quesadilla_office_lightson'}
# full {0}
# loading data...:  87%|████████▋ | 128/147 [18:52<03:57, 12.51s/it]
# using sliced_quesadilla_office_lightson.0 (21240, 3) {'full', 'super_simple'} (21240, 512)
# loading data...:  88%|████████▊ | 130/147 [18:52<01:49,  6.42s/it]
# Skipping: sliced_quesadilla_office_lightson: 8
# Skipping: sliced_quesadilla_office_lightson: 1
# loading data...:  88%|████████▊ | 130/147 [18:53<01:49,  6.42s/it]
# super_simple {'peanut-butter_orangeroom_lightson'}
# super_simple {0}
# full {'peanut-butter_orangeroom_lightson'}
# full {0}
# loading data...:  89%|████████▉ | 131/147 [19:14<02:54, 10.88s/it]
# using peanut-butter_orangeroom_lightson.0 (23364, 3) {'full', 'super_simple'} (23364, 512)
# Skipping: sliced_quesadilla_window: 2
# super_simple {'sliced_quesadilla_window'}
# super_simple {0}
# full {'sliced_quesadilla_window'}
# full {0}
# loading data...:  90%|█████████ | 133/147 [19:34<02:26, 10.46s/it]
# using sliced_quesadilla_window.0 (21864, 3) {'full', 'super_simple'} (21864, 512)
# super_simple {'sliced_quesadilla_window'}
# super_simple {1}
# full {'sliced_quesadilla_window'}
# full {1}
# loading data...:  91%|█████████ | 134/147 [19:54<02:46, 12.82s/it]
# using sliced_quesadilla_window.1 (22068, 3) {'full', 'super_simple'} (22068, 512)
# super_simple {'plain_office_lightson'}
# super_simple {0}
# full {'plain_office_lightson'}
# full {0}
# loading data...:  92%|█████████▏| 135/147 [20:19<03:10, 15.88s/it]
# using plain_office_lightson.0 (27036, 3) {'full', 'super_simple'} (27036, 512)
# super_simple {'plain_office_lightsoff'}
# super_simple {0}
# loading data...:  93%|█████████▎| 136/147 [20:32<02:45, 15.07s/it]
# using plain_office_lightsoff.0 (27612, 2) {'super_simple'} (27612, 512)
# super_simple {'plain_printerroom_lightsoff'}
# super_simple {0}
# full {'plain_printerroom_lightsoff'}
# full {0}
# loading data...:  93%|█████████▎| 137/147 [20:49<02:36, 15.66s/it]
# using plain_printerroom_lightsoff.0 (18852, 3) {'full', 'super_simple'} (18852, 512)
# super_simple {'peanut-butter_nursingroom_lightson'}
# super_simple {0}
# full {'peanut-butter_nursingroom_lightson'}
# full {0}
# loading data...:  94%|█████████▍| 138/147 [21:10<02:36, 17.39s/it]
# using peanut-butter_nursingroom_lightson.0 (24096, 3) {'full', 'super_simple'} (24096, 512)
# super_simple {'rolled_kitchen_lightson'}
# super_simple {2}
# full {'rolled_kitchen_lightson'}
# full {2}
# loading data...:  95%|█████████▍| 139/147 [21:28<02:19, 17.47s/it]
# using rolled_kitchen_lightson.2 (19560, 3) {'full', 'super_simple'} (19560, 512)
# Skipping: rolled_kitchen_lightson: 5
# super_simple {'rolled_kitchen_lightson'}
# super_simple {0}
# full {'rolled_kitchen_lightson'}
# full {0}
# loading data...:  96%|█████████▌| 141/147 [21:49<01:26, 14.34s/it]
# using rolled_kitchen_lightson.0 (22128, 3) {'full', 'super_simple'} (22128, 512)
# super_simple {'tortilla_nutella_banana_orange_booth_lightsoff'}
# super_simple {0}
# loading data...:  97%|█████████▋| 142/147 [22:03<01:10, 14.13s/it]
# using tortilla_nutella_banana_orange_booth_lightsoff.0 (27636, 2) {'super_simple'} (27636, 512)
# super_simple {'package_kitchen_lightsoff'}
# super_simple {0}
# full {'package_kitchen_lightsoff'}
# full {0}
# loading data...:  97%|█████████▋| 143/147 [22:23<01:02, 15.65s/it]
# using package_kitchen_lightsoff.0 (21060, 3) {'full', 'super_simple'} (21060, 512)
# Skipping: peanut-butter_kitchen_lightson: 2
# super_simple {'peanut-butter_kitchen_lightson'}
# super_simple {0}
# full {'peanut-butter_kitchen_lightson'}
# full {0}
# loading data...:  99%|█████████▊| 145/147 [22:44<00:27, 13.57s/it]
# using peanut-butter_kitchen_lightson.0 (22572, 3) {'full', 'super_simple'} (22572, 512)
# super_simple {'plain_stairwell_as-is'}
# super_simple {0}
# full {'plain_stairwell_as-is'}
# full {0}
# loading data...:  99%|█████████▉| 146/147 [23:06<00:15, 15.45s/it]
# using plain_stairwell_as-is.0 (22644, 3) {'full', 'super_simple'} (22644, 512)
# super_simple {'peanut-butter_kitchen_lightsoff'}
# super_simple {0}
# full {'peanut-butter_kitchen_lightsoff'}
# full {0}
# loading data...: 100%|██████████| 147/147 [23:30<00:00,  9.60s/it]
# using peanut-butter_kitchen_lightsoff.0 (23196, 3) {'full', 'super_simple'} (23196, 512)
# (1847172, 8)
#    index    object super_simple_state  full_state  track_id  \
# 0    150  tortilla         in-package  in-package         0
# 1    150  tortilla         in-package  in-package         0
# 2    150  tortilla         in-package  in-package         0
# 3    150  tortilla         in-package  in-package         0
# 4    150  tortilla         in-package  in-package         0
#
#                    video_id  augmented  \
# 0  package_office_lightsoff      False
# 1  package_office_lightsoff       True
# 2  package_office_lightsoff       True
# 3  package_office_lightsoff       True
# 4  package_office_lightsoff       True
#
#                                               vector
# 0  [-0.0064577176, -0.02735838, -0.004913109, 0.0...
# 1  [0.013264829, -0.031655245, 0.02115491, 0.0367...
# 2  [0.0021488245, -0.03510011, 0.011682416, 0.039...
# 3  [-0.041702792, -0.005873336, 0.009336288, 0.02...
# 4  [0.0009789644, -0.007694316, 0.0018491548, 0.0...

# %%
df.to_pickle(f"{cfg.DATASET.ROOT}/embs.npz")

# %%
df.super_simple_state.value_counts()
# Out:
# super_simple_state
# pb+jelly          283848
# nutella           275388
# nutella+banana    262020
# plain             250968
# peanut-butter     237036
# in-package        219528
# rolled            172536
# cut               145848
# Name: count, dtype: int64

# %%
odf = df[(df.object == 'tortilla') & (df.video_id.str.contains('office')) & ~df.augmented]
odf.shape
# Out:
# (24339, 8)

# %%
odf.super_simple_state.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/bea/ptg/object-states/scripts/Dump DB.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blugia/home/bea/ptg/object-states/scripts/Dump%20DB.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> odf.super_simple_state.value_counts()
#
# NameError: name 'odf' is not defined

# %%
X = np.array(list(odf.vector.values))
X.shape
# Out:
# (24339, 512)

# %%
y = odf.super_simple_state.values
y.shape
# Out:
# (24339,)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(15, 8))

# %%
# Step 0: Normalization
scaler = StandardScaler()
Z_norm = scaler.fit_transform(X)

# Step 1: PCA
pca = PCA(n_components=30)  # Choose the number of components based on your data
Z_pca = pca.fit_transform(Z_norm)
Z_pca.shape
# Out:
# (24339, 30)

# %%
plt.figure(figsize=(15, 15))
for yi in np.unique(y):
    plt.scatter(Z_pca[y==yi, 0], Z_pca[y==yi, 1], label=yi, alpha=0.4)
plt.legend()

# %%
# from sklearn.manifold import Isomap

# proj = Isomap(n_components=2)
# Zt = proj.fit_transform(X)
# Zt.shape

# %%
# plt.figure(figsize=(15, 15))
# for yi in np.unique(y):
#     plt.scatter(Zt[y==yi, 0], Zt[y==yi, 1], label=yi, alpha=0.4)
# plt.legend()

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2)
Z_tsne = tsne.fit_transform(X)
Z_tsne.shape
# Out:
# (24339, 2)

# %%
plt.figure(figsize=(12, 12))
for yi in np.unique(y):
    plt.scatter(Z_tsne[y==yi, 0], Z_tsne[y==yi, 1], label=yi, alpha=0.4)
plt.legend()

# %%
dump_db(tree.db_fname.format(emb_type="clip_office_noaug"), odf)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# tortilla 24339
#               index      track_id
# count  24339.000000  24339.000000
# mean    1175.280784      0.198324
# std      585.736135      0.530122
# min      116.000000      0.000000
# 25%      688.000000      0.000000
# 50%     1156.000000      0.000000
# 75%     1631.000000      0.000000
# max     2771.000000      2.000000
# 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
